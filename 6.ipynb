# %% [markdown]
# The Autocorrelation Function (ACF) and Partial Autocorrelation Function (PACF) plots are crucial tools in time series analysis, particularly for identifying the order of Autoregressive Integrated Moving Average (ARIMA) models. ARIMA models are characterized by three parameters:
# �
# p (autoregressive order),
# �
# d (degree of differencing), and
# �
# q (moving average order). ACF and PACF plots help in determining the appropriate values of
# �
# p and
# �
# q for modeling.
#
# Autocorrelation Function (ACF)
# The ACF measures the correlation between time series observations at different lags, essentially showing how well the current value of the series is related to its past values. In the context of ARIMA model selection:
#
# ACF Plot for
# �
# q (MA parameter): The ACF plot can help identify the moving average part of an ARIMA model, denoted by
# �
# q. For an MA(q) process, the ACF will typically show significant autocorrelations up to the
# �
# q-th lag, after which it should taper off towards zero fairly quickly.
# Partial Autocorrelation Function (PACF)
# The PACF measures the correlation between observations at different lags while controlling for the correlations at all shorter lags. It isolates the direct effect of past observations on the current value, removing the influence of intermediary values. In ARIMA model selection:
#
# PACF Plot for
# �
# p (AR parameter): The PACF plot is used to identify the autoregressive part of an ARIMA model, denoted by
# �
# p. For an AR(p) process, the PACF will typically show significant correlations up to the
# �
# p-th lag, with correlations near zero beyond the
# �
# p-th lag.
# Identifying ARIMA Orders with ACF and PACF
# Determine
# �
# d: Before analyzing ACF and PACF for
# �
# p and
# �
# q, the series should be made stationary, often by differencing (
# �
# d). The appropriate level of differencing (
# �
# d) is the minimum number needed to achieve stationarity.
#
# Use PACF to Estimate
# �
# p: Once the series is stationary, examine the PACF plot to determine the order of the autoregressive part (
# �
# p). Look for the lag after which most partial autocorrelations become insignificant (close to zero).
#
# Use ACF to Estimate
# �
# q: Similarly, examine the ACF plot to determine the order of the moving average part (
# �
# q). Look for the lag after which most autocorrelations become insignificant.
#
# Practical Considerations
# The "cut-off" point in the PACF plot for an AR component (
# �
# p) and in the ACF plot for an MA component (
# �
# q) can sometimes be subjective. Statistical significance tests and model selection criteria (like AIC, BIC) should also guide the choice.
# Real-world data may not follow theoretical models perfectly, and both plots should be used in conjunction. Sometimes, iterative fitting and model comparison are necessary to identify the best model.
# The presence of significant spikes at seasonal lags in the ACF and PACF plots may indicate a need for seasonal differencing or the inclusion of seasonal ARIMA components.
